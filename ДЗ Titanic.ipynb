# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('ДЗ_данные_titanic.csv' , delimiter=',')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                         Name Passenger Gender Passenger   Age  \
# 0                              Braund, Mr. Owen Harris             male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           female  38.0
# 2                               Heikkinen, Miss. Laina           female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           female  35.0
# 4                             Allen, Mr. William Henry             male  35.0
# ...

# %%
df = pd.read_csv('ДЗ_данные_titanic - titanic.csv')

# %%
# Задание 1.а  Сколько столцбов и сколько строк в сохраненном DataFrame
df.shape
# Out:
# (891, 12)

# %%
# Задание 1.b Какой объем памяти занимает  DataFrame
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       891 non-null    int64
#  1   Survived          891 non-null    int64
#  2   Pclass            891 non-null    int64
#  3   Name Passenger    891 non-null    object
#  4   Gender Passenger  891 non-null    object
#  5   Age               714 non-null    float64
#  6   SibSp             891 non-null    int64
#  7   Parch             891 non-null    int64
#  8   Ticket            891 non-null    object
#  9   Fare              891 non-null    float64
#  10  Cabin             204 non-null    object
#  11  Embarked          889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Задание 1.с Сколько столбцов разных типов
df.dtypes
# Out:
# PassengerId           int64
# Survived              int64
# Pclass                int64
# Name Passenger       object
# Gender Passenger     object
# Age                 float64
# SibSp                 int64
# Parch                 int64
# Ticket               object
# Fare                float64
# Cabin                object
# Embarked             object
# dtype: object

# %%
# Задание 2  Привести названия всех столбцов к виду: все названия строчной буквы 
df.columns = df.columns.str.lower()

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                         name passenger gender passenger   age  \
# 0                              Braund, Mr. Owen Harris             male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           female  38.0
# 2                               Heikkinen, Miss. Laina           female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           female  35.0
# 4                             Allen, Mr. William Henry             male  35.0
# ...

# %%
# Задание 3  Вывести статистику по каждому столбцу:а) для категориальных переменных:количество уникальных значений, моду,
# количество пропущенных значений
df.nunique()
# Out:
# passengerid         891
# survived              2
# pclass                3
# name passenger      891
# gender passenger      2
# age                  88
# sibsp                 7
# parch                 7
# ticket              681
# fare                248
# cabin               147
# embarked              3
# dtype: int64

# %%
# вывести моду
df.mode()
# Out:
#      passengerid  survived  pclass                         name passenger  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#     gender passenger   age  sibsp  parch    ticket  fare        cabin embarked
# ...

# %%
# вывести количество пропущенных значений
df_sub = df.isna().sum()
df_sub[df_sub > 0]
# Out:
# age         177
# cabin       687
# embarked      2
# dtype: int64

# %%
#Задание 3 b) Для интервальных: медиану, среднее, квантиль 90, квантиль 10, максимальное значение, минимальное значение, 
# количество пропущенных значений
print ('Максимум:', df.max())
print ('Минимум:', df.min())
print ('Среднее:', df.mean())
print ('Медиана:', df.median())
# Out:
# Максимум: passengerid                                 891
# survived                                      1
# pclass                                        3
# name passenger      van Melkebeke, Mr. Philemon
# gender passenger                           male
# age                                        80.0
# sibsp                                         8
# parch                                         6
# ticket                                WE/P 5735
# fare                                   512.3292
# dtype: object
# Минимум: passengerid                           1
# survived                              0
# pclass                                1
# name passenger      Abbing, Mr. Anthony
# gender passenger                 female
# age                                0.42
# sibsp                                 0
# parch                                 0
# ticket                           110152
# fare                                0.0
# dtype: object
# ...

# %%
# вывести квантиль 90, квантиль 10
df.quantile([0.10,0.90])
# Out:
# C:\Users\fedor\AppData\Local\Temp\ipykernel_17300\2567539373.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile([0.10,0.90])
#      passengerid  survived  pclass   age  sibsp  parch     fare
# 0.1         90.0       0.0     1.0  14.0    0.0    0.0   7.5500
# 0.9        802.0       1.0     3.0  50.0    1.0    2.0  77.9583

# %%
# # вывести количество пропущенных значений
df.isnull().sum()
# Out:
# passengerid           0
# survived              0
# pclass                0
# name passenger        0
# gender passenger      0
# age                 177
# sibsp                 0
# parch                 0
# ticket                0
# fare                  0
# cabin               687
# embarked              2
# dtype: int64

# %%
#Задание 4 Посчитать долю выживших пассажиров
df['survived'].mean()
# Out:
# 0.3838383838383838

# %%
#Задание 5 Посчитать долю и количество выживших пассажиров в зависимости от: а) класса каюта 
df.groupby('pclass')[['survived']]. sum()
# Out:
#         survived
# pclass
# 1            136
# 2             87
# 3            119

# %%
df.groupby('pclass')[['survived']]. mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
#Задание 5 Посчитать долю и количество выживших пассажиров в зависимости от: b) пол пассажира 
df.groupby('gender passenger')[['survived']]. sum()
# Out:
#                   survived
# gender passenger
# female                 233
# male                   109

# %%
df.groupby('gender passenger')[['survived']]. mean()
# Out:
#                   survived
# gender passenger
# female            0.742038
# male              0.188908

# %%
#Задание 5 Посчитать долю и количество выживших пассажиров в зависимости от: b) порт посадки
df.groupby('embarked')[['survived']]. sum()
# Out:
#           survived
# embarked
# C               93
# Q               30
# S              217

# %%
df.groupby('embarked')[['survived']]. mean()
# Out:
#           survived
# embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
#Задание 5 Посчитать долю и количество выживших пассажиров в зависимости от: c) одновременно пол и класса каюты
df.groupby(['gender passenger','pclass'])['survived']. sum()
# Out:
# gender passenger  pclass
# female            1         91
#                   2         70
#                   3         72
# male              1         45
#                   2         17
#                   3         47
# Name: survived, dtype: int64

# %%
df.groupby(['gender passenger','pclass'])['survived']. mean()
# Out:
# gender passenger  pclass
# female            1         0.968085
#                   2         0.921053
#                   3         0.500000
# male              1         0.368852
#                   2         0.157407
#                   3         0.135447
# Name: survived, dtype: float64

# %%
#Задание 6 Постройте информативные графики, по которым можно понять зависимость выживших от пола, класса каюты, порта посадки
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Задание 6 График зависимости выживших от класса каюты
sns.barplot(data=df, x="pclass", y="survived", estimator=np.sum)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
#Задание 6 График зависимости выживших от пола
sns.barplot(data=df, x="gender passenger", y="survived", estimator=np.sum)
# Out:
# <Axes: xlabel='gender passenger', ylabel='survived'>

# %%
#Задание 6 График зависимости выживших от порта посадки
sns.barplot(data=df, x="embarked", y="survived", estimator=np.sum)
# Out:
# <Axes: xlabel='embarked', ylabel='survived'>
